# %% [markdown]
# ### Image to Pencil Sketch with Python:
#
# We need to read the image in RBG format and then convert it to a grayscale image. This will turn an image into a classic black and white photo. Then the next thing to do is invert the grayscale image also called negative image, this will be our inverted grayscale image. Inversion can be used to enhance details. Then we can finally create the pencil sketch by mixing the grayscale image with the inverted blurry image. This can be done by dividing the grayscale image by the inverted blurry image. Since images are just arrays, we can easily do this programmatically using the divide function from the cv2 library in Python.

# %% [markdown]
# #### Author: Thilagavathy R Vasantharaja

# %%
pip install opencv-python #Open Source Computer Vision Library
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import matplotlib.pyplot as plt
plt.style.use('seaborn')

# %%
#read in the image
img = cv2.imread('C:\\Users\\vasanth\\Desktop\\Anaconda1\\Anaconda\\Internship\\LetsGrowMore\\Peacock_image.jpg')

# %%
#cv2.imshow("Peacock_image", img)
#cv2.waitKey(0)
#cv2.imwrite("Peacock_image", img)
plt.figure(figsize=(8,8))
plt.imshow(img)
plt.axis("off")
plt.title("RBG image")
plt.show()

# %%
gray_image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
S
#cv2.imshow("GrayScale Peacock", gray_image)
#cv2.waitKey(0)

# %%
inverted_image = 255 - gray_image
plt.figure(figsize=(8,8))
plt.imshow(inverted_image,cmap='gray')
plt.axis("off")
plt.title("Inverted Image")
plt.show()
#cv2.imshow("Inverted", inverted_image)
#cv2.waitKey()

# %%
blurred = cv2.GaussianBlur(inverted_image, (21, 21), 0)

# %%
inverted_blurred = 255 - blurred
pencil_sketch = cv2.divide(gray_image, inverted_blurred, scale=256.0)
plt.figure(figsize=(8,8))
plt.imshow(pencil_sketch,cmap='gray')
plt.axis("off")
plt.title("Pencil_Sketch")
plt.show()
#cv2.imshow("Sketch", pencil_sketch)
#cv2.waitKey(0)

# %%
#cv2.imshow("original image", img)
#cv2.imshow("pencil sketch", pencil_sketch)
#cv2.waitKey(0)
plt.figure(figsize=(20,20))
plt.subplot(1,2,1)
plt.imshow(img)
plt.axis("off")
plt.title("RBG Image")
plt.subplot(1,2,2)
plt.imshow(pencil_sketch)
plt.axis("off")
plt.title("Pencil Image")
# Out:
# Text(0.5, 1.0, 'Pencil Image')
